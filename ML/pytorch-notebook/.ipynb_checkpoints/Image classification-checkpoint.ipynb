# %%
import pandas as pd

# %%
from sklearn import preprocessing

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#             id                                               name  \
# 0            0  b488 Moto Guzzi Motorcycle LED Neon Light Sign...
# 1            1  2017 Promotion New t shirt men course moto guz...
# 2            2  MOTO GUZZI ANNI 1921-2011 T-shirt Top Lycra Co...
# 3            4  2x Stainless Steel Front Brake Rotors Disc Bra...
# 4            5  MOTO GUZZI ANNI 1921-2011 T-shirt Top Lycra Co...
# 5            6  1/22 Scale Italeri Motorcycle Model Diecast Mi...
# 6            7  Free delivery Fit MOTO GUZZI AUDACE ELDORADO M...
# 7            8  Pair Steel Front Brake Rotors Disc Braking Dis...
# 8           11  motorcycle brake clutch levers & 22mm handleba...
# 9           12  motorcycle brake clutch levers & 22mm handleba...
# 10          13  3 color motorcycle handle bar grip 22MM levers...
# 11          14  Collectible Deagostini Novarra Italy 1/24 Scal...
# 12          15  Free shipping Fit MOTO GUZZI GRISO NORGE 1200/...
# ...

# %%
images = df[['id','image']]

# %%
data = df.groupby('category').count().sort_values('image')

# %%
filteredCategory = data[data['id'] > 100].index

# %%
cleaned = df[df['category'].isin(filteredCategory)]

# %%
res = cleaned.reset_index(drop=True)

# %%
res
# Out:
#            id                                               name  \
# 0           0  b488 Moto Guzzi Motorcycle LED Neon Light Sign...
# 1           1  2017 Promotion New t shirt men course moto guz...
# 2           2  MOTO GUZZI ANNI 1921-2011 T-shirt Top Lycra Co...
# 3           4  2x Stainless Steel Front Brake Rotors Disc Bra...
# 4           5  MOTO GUZZI ANNI 1921-2011 T-shirt Top Lycra Co...
# 5           6  1/22 Scale Italeri Motorcycle Model Diecast Mi...
# 6           7  Free delivery Fit MOTO GUZZI AUDACE ELDORADO M...
# 7           8  Pair Steel Front Brake Rotors Disc Braking Dis...
# 8          11  motorcycle brake clutch levers & 22mm handleba...
# 9          12  motorcycle brake clutch levers & 22mm handleba...
# 10         13  3 color motorcycle handle bar grip 22MM levers...
# 11         14  Collectible Deagostini Novarra Italy 1/24 Scal...
# 12         15  Free shipping Fit MOTO GUZZI GRISO NORGE 1200/...
# ...

# %%
res.to_csv("cleaned2.csv")
