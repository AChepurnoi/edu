# %% [markdown]
# # Word sense disambiguation with Simplified Lesk for Ukrainian

# %% [markdown]
# ## Senses
#
# Send requests to http://sum.in.ua/ to collect senses for a word.

# %%
from lxml import html
import requests
import numpy as np
import math

# %%
# http://sum.in.ua/ uses custom transliteration

conversion = {
    u'\u0410' : 'A',    u'\u0430' : 'a',
    u'\u0411' : 'B',    u'\u0431' : 'b',
    u'\u0412' : 'V',    u'\u0432' : 'v',
    u'\u0413' : 'Gh',    u'\u0433' : 'gh',
    u'\u0490' : 'G',    u'\u0491' : 'g',
    u'\u0414' : 'D',    u'\u0434' : 'd',
    u'\u0415' : 'E',    u'\u0435' : 'e',
    u'\u0404' : 'Ye',   u'\u0454' : 'je',
    u'\u0416' : 'Zh',   u'\u0436' : 'zh',
    u'\u0417' : 'Z',    u'\u0437' : 'z',
    u'\u0418' : 'Y',    u'\u0438' : 'y',
    u'\u0406' : 'I',    u'\u0456' : 'i',
    u'\u0407' : 'Ji',   u'\u0457' : 'ji',
    u'\u0419' : 'J',    u'\u0439' : 'j',
    u'\u041a' : 'K',    u'\u043a' : 'k',
    u'\u041b' : 'L',    u'\u043b' : 'l',
    u'\u041c' : 'M',    u'\u043c' : 'm',
    u'\u041d' : 'N',    u'\u043d' : 'n',
    u'\u041e' : 'O',    u'\u043e' : 'o',
    u'\u041f' : 'P',    u'\u043f' : 'p',
    u'\u0420' : 'R',    u'\u0440' : 'r',
    u'\u0421' : 'S',    u'\u0441' : 's',
    u'\u0422' : 'T',    u'\u0442' : 't',
    u'\u0423' : 'U',    u'\u0443' : 'u',
    u'\u0424' : 'F',    u'\u0444' : 'f',
    u'\u0425' : 'Kh',    u'\u0445' : 'kh',
    u'\u0426' : 'C',   u'\u0446' : 'c',
    u'\u0427' : 'Ch',   u'\u0447' : 'ch',
    u'\u0428' : 'Sh',   u'\u0448' : 'sh',
    u'\u0429' : 'Shh',  u'\u0449' : 'shh',
    u'\u044c' : 'j',
    u'\u042e' : 'Ju',   u'\u044e' : 'ju',
    u'\u042f' : 'Ja',   u'\u044f' : 'ja',
    u'\'' : '.'
}

def transliterate(word):
    translit = []
    for c in word:
        translit.append(conversion.get(c, c))
    return ''.join(translit)

# %%
print(transliterate("серце"))
print(transliterate("знущається"))
print(transliterate("бур'ян"))
# Out:
# serce
# znushhajetjsja
# bur.jan

# %%
URL = "http://sum.in.ua/s/"

def get_senses(word):
    """
    Extract senses for WORD from the dictionary.
    """
    word = transliterate(word)
    page = requests.get(URL + word)
    tree = html.fromstring(page.text)
    senses = tree.xpath("//p[@class='znach']")
    print(len(senses), "senses found.")
    return list(enumerate([" ".join(i.xpath('text()')) for i in senses], 1))

# %%
word = "лист"
senses = get_senses(word)
print(senses[2][1])
# Out:
# 5 senses found.
#  Тонкий, щільний шматок або шар
# якого-небудь матеріалу (паперу, заліза, фанери і т. ін.).
# Газорізальник Мамайчук-старший.. щось викроює з
# товстого сталевого листа  ;
# Цілий вечір Мишуня казився й дурів.. Зачепив неумисно
# й перекинув відро з водою. Упустив фанерного листа,
# на якому лежало тісто  ;
# Шиферний лист іде на покрівлю житлових і промислових
# будівель  .

# %% [markdown]
# ## Collect sentenses from the brown-uk corpus
#
# Read files from https://github.com/brown-uk/corpus/tree/master/data/good. Find all sentences that contain the word in question.
#
# Use https://github.com/lang-uk/tokenize-uk for tokenization:
# pip install tokenize_uk
#
# and https://github.com/kmike/pymorphy2 for lemmatization:
#
# pip install -U https://github.com/kmike/pymorphy2/archive/master.zip#egg=pymorphy2
#
# pip install -U pymorphy2-dicts-uk

# %%
import os
import re
import pymorphy2
import tokenize_uk

CORPUS_PATH = "data/good/"

morph = pymorphy2.MorphAnalyzer(lang='uk')

# %%
def find_sentences(text, word):
    """
    From TEXT select sentences that contain WORD.
    """
    sentences_w_word = []
    paragraphs = tokenize_uk.tokenize_text(text)
    for paragraph in paragraphs:
        for sentence in paragraph:
            for token in sentence:
                if morph.parse(token)[0].normal_form == word:
                    sentences_w_word.append(sentence)
                    break
    return sentences_w_word

# %%
data = []

for filename in os.listdir(CORPUS_PATH):
    with open(CORPUS_PATH + filename, "r") as f:
        text = f.read()
    body = text[text.find("<body>"):]
    body = re.sub(r"<[^<>]+>", "", body)
    data += find_sentences(body, word)

print(len(data))
# Out:
# 94

# %%
data[0]
# Out:
# ['До',
#  'речі',
#  ',',
#  'тоді',
#  'ж',
#  'було',
#  'вирішено',
#  ',',
#  'що',
#  'після',
#  'двотижневого',
#  'перебування',
#  'по',
#  'домівках',
#  'усі',
#  'знову',
#  'зберуться',
#  'до',
#  'козацького',
#  'війська',
#  ',',
#  'щоб',
#  'заслухати',
#  '«',
#  'реляцію',
#  ',',
#  'яку',
#  'привезуть',
#  'посли',
#  '»',
#  '.',
#  '29',
#  'червня',
#  'в',
#  'Чигирині',
#  'знову',
#  'збирається',
#  '«',
#  'чорна',
#  '»',
#  'рада',
#  'для',
#  'заслухання',
#  'листа',
#  'від',
#  'А',
#  '.',
#  'Кисіля',
#  'та',
#  'підготовки',
#  'відповіді',
#  '.']

# %% [markdown]
# ## Implement Simplified Lesk

# %% [markdown]
# ### 1. Collect context words from senses
#
# Tokenize, downcase, lemmatize, and remove stop-words.

# %%
def collect_bow(text):
    """
    Tokenize TEXT with tokenize_uk, lemmatize TEXT with pymorphy2,
    and remove functional words.
    """
    tokens = tokenize_uk.tokenize_words(text)
    bow = []
    for token in tokens:
        parse = morph.parse(token)[0]
        if parse.tag.POS not in {'NUMR', 'NPRO', 'PREP', 'CONJ', 'PRCL'} and \
            not 'PNCT' in parse.tag and \
            not token.isdigit() and \
            token not in ['до', 'на', 'за', 'його']:
            bow.append(parse.normal_form)
    return set(bow)

# %%
collect_bow(senses[0][1])
# Out:
# {'біла',
#  'вертати',
#  'вигляд',
#  'виконати',
#  'виноградний',
#  'вирізуватися',
#  'вусик',
#  'відро',
#  'газообмін',
#  'глек',
#  'головка',
#  'диво',
#  'дунай',
#  'дівчина',
#  'живлення',
#  'звичайно',
#  'згинути',
#  'зелений',
#  'зон',
#  'капуста',
#  'капустяний',
#  'кращий',
#  'краяти',
#  'лист',
#  'лівий',
#  'літ',
#  'маланчин',
#  'марний',
#  'метр',
#  'молоко',
#  'місячний',
#  'на',
#  'назад',
#  'найти',
#  'ніжно',
#  'опадати',
#  'орган',
#  'падіння',
#  'паляниця',
#  'переворот',
#  'петля',
#  'плавно',
#  'пластинка',
#  'поволі',
#  'повітряний',
#  'право',
#  'піти',
#  'раз',
#  'рок',
#  'рослина',
#  'ріка',
#  'світа',
#  'селянський',
#  'сир',
#  'складовий',
#  'сонце',
#  'сторонець',
#  'стояти',
#  'сяйво',
#  'темрява',
#  'терти',
#  'тонкий',
#  'тремтіти',
#  'упливати',
#  'частина',
#  'чужий',
#  'штольц'}

# %%
collect_bow(data[0])
# Out:
# {'бути',
#  'вирішити',
#  'відповідь',
#  'військо',
#  'двотижневий',
#  'до',
#  'домівка',
#  'заслухання',
#  'заслухати',
#  'збиратися',
#  'знову',
#  'зібратися',
#  'кисіль',
#  'козацький',
#  'лист',
#  'перебування',
#  'посол',
#  'привезти',
#  'підготовка',
#  'після',
#  'рад',
#  'реляція',
#  'річ',
#  'червень',
#  'чигирин',
#  'чорна'}

# %% [markdown]
# ### 2. Define the best sense for the word
#
# Find the sense that has the biggest overlap with the word context. Use sense 1 as default.

# %%
signatures = [(idx, collect_bow(sense)) for idx, sense in senses]

def classify(sentence, word, senses, log=False):
    """
    Find the sense that has the biggest overlap with the word context.
    Use sense 1 as default.
    """
    context = collect_bow(sentence)
    best_sense = 1
    max_overlap = 0
    max_overlap_words = []
    for sense_id, signature in signatures:
        overlap = context.intersection(signature)
        
#         if score == max_overlap and sense_id == 4:
#             best_sense = sense_id
#             max_overlap_words = overlap
            
        
        if len(overlap) > max_overlap:
            max_overlap_words = overlap
            max_overlap = len(overlap)
            best_sense = sense_id
        
    if log:
        print(" ".join(sentence))
        print("Best sense:", best_sense)
        print("{} words overlap: {}.\n".format(max_overlap, ", ".join(max_overlap_words)))
    return best_sense

# %%
senses[1]
# Out:
# (2,
#  '   у. Те саме, що  . — Я б прикрила твій\nслід листом, щоб його вітер не завіяв, піском не замів, —\nсказала Мелашка  ; Ах, яке ж\nсинє й зоряне небо! І запах цегли — руїн, жовтого\nлисту — аж у голову хмелем  ;\n \xa0 Засушене, рідше свіже листя деяких рослин, що\nвикористовується як приправа або для виготовлення напою\nчи ліків. Яких вже мені ліків не завдавали! Лукаш мене\nнапував листом от чорних порічок  ; Дівчата онде подались Збирати свіжий лист із чаю\n ; Не поспішаючи, він кладе\nв казанок.. сіль, дрібно покришену й підсмажену цибулю\nі лавровий лист  .')

# %%
classify(data[0], word, signatures, log=True)
# Out:
# До речі , тоді ж було вирішено , що після двотижневого перебування по домівках усі знову зберуться до козацького війська , щоб заслухати « реляцію , яку привезуть посли » . 29 червня в Чигирині знову збирається « чорна » рада для заслухання листа від А . Кисіля та підготовки відповіді .
# Best sense: 4
# 3 words overlap: військо, після, лист.
# 4

# %%
classify(data[1], word, signatures, log=True)
# Out:
# Про ці обставини директор краєзнавчого музею неодноразово листами повідомляв голів Любомльської райдержадміністрації та районної ради , а також управління культури Волинської облдержадміністрації .
# Best sense: 4
# 2 words overlap: лист, про.
# 4

# %%
classify(data[2], word, signatures, log=True)
# Out:
# Через кілька років народиться і другий цикл — « Кримські відгуки » , до якого увійдуть « Імпровізація » , « Уривки з листа » , « Мрії » , драматична поема « Іфігенія в Тавриді » , « Весна зимова » … Цей цикл — усе пережите Лесею в Ялті з червня 1897 до червня 1898 року …
# Best sense: 1
# 2 words overlap: рок, лист.
# 1

# %%
classify(data[10], word, signatures, log=True)
# Out:
# Розказував Рей про свої шкільні роки і спонукав її до написання листа керівництву залізниці , адже це так важливо — отримати освіту .
# Best sense: 4
# 2 words overlap: лист, про.
# 4

# %%
classify(data[50], word, signatures, log=True)
# Out:
# – складення та подання відкритих листів до влади та впливових осіб ;
# Best sense: 4
# 2 words overlap: особа, лист.
# 4

# %%
classify(data[60], word, signatures, log=True)
# Out:
# Тимчасом приходить ще один лист - від музикантки , яку так давно люблю .
# Best sense: 1
# 1 words overlap: лист.
# 1

# %%
from collections import Counter

sense_counts = []
for i in range(len(data)):
    sense_id = classify(data[i], word, signatures)
    sense_counts.append(sense_id)
Counter(sense_counts)
# Out:
# Counter({4: 28, 1: 52, 5: 2, 2: 7, 3: 5})

# %%
test_data = data[:50]

# %%
test_labels = [classify(x, word, signatures) for x in test_data]

# %%
senses
# Out:
# [(1,
#   '   а. Орган повітряного живлення і\nгазообміну рослин у вигляді тонкої, звичайно зеленої\nпластинки. Лист за листом опадає, Рік за роком\nупливає. Назад не вертає!  ;\nВиноградний лист вирізується з темряви й ніжно тремтить\nразом з тонким вусиком у місячному сяйві  ; \xa0  А я піду на край світа... На\nчужій сторонці Найду кращу [дівчину] або згину, Як\nтой лист на сонці  ; Пішли літа\n[Маланчині] марне з світа, як лист по Дунаю...\n ;  \xa0 Складова частина головки\nкапусти. У відрі стоїть глек з молоком, сир у капустяному\nлисті, біла селянська паляниця  ;\n \xa0   листом,   — плавно, поволі.\n[Штольц:] В зоні виконати, три петлі, два праві й\nдва ліві перевороти.. Падіння листом до шестисот\nметрів  .\n    див.  .\n'),
#  (2,
#   '   у. Те саме, що  . — Я б прикрила твій\nслід листом, щоб його вітер не завіяв, піском не замів, —\nсказала Мелашка  ; Ах, яке ж\nсинє й зоряне небо! І запах цегли — руїн, жовтого\nлисту — аж у голову хмелем  ;\n \xa0 Засушене, рідше свіже листя деяких рослин, що\nвикористовується як приправа або для виготовлення напою\nчи ліків. Яких вже мені ліків не завдавали! Лукаш мене\nнапував листом от чорних порічок  ; Дівчата онде подались Збирати свіжий лист із чаю\n ; Не поспішаючи, він кладе\nв казанок.. сіль, дрібно покришену й підсмажену цибулю\nі лавровий лист  .'),
#  (3,
#   ' Тонкий, щільний шматок або шар\nякого-небудь матеріалу (паперу, заліза, фанери і т. ін.).\nГазорізальник Мамайчук-старший.. щось викроює з\nтовстого сталевого листа  ;\nЦілий вечір Мишуня казився й дурів.. Зачепив неумисно\nй перекинув відро з водою. Упустив фанерного листа,\nна якому лежало тісто  ;\nШиферний лист іде на покрівлю житлових і промислових\nбудівель  .\n'),
#  (4,
#   ' Писаний текст, признач. для повідомлення про\nщо-небудь, для спілкування з кимось на відстані, а\nтакож відповідна поштова кореспонденція. По копійці\nзаробляла [вдова], Копу назбирала. Та до сина лист\nписала, У військо послала — Полегшало  ; Аж двічі Павло прочитав листа зряду. І, як\nце й завжди бувало з ним після Корнійових листів,\nтрохи полегшало ніби  ; — Вам,\nПолю, ось газетки і рекомендований лист, — дістала\nлистоноша пошту з керзової сумки  ;  \xa0 Писане звертання до особи або осіб,\nрозраховане на широке розповсюдження. Кожний студент\nзнає знаменитий лист Бєлінського, як він писав про\nГоголя  .\n'),
#  (5,
#   ' який. Офіційний, грошовий або інший документ.\n[Йоганна (після мовчання):] Хузане, дай мені\nрозлучний лист  ;  \xa0 Документ\nдля записування яких-небудь відомостей. Вони\n[обліковці] обійдуть квартиру за квартирою..,\nзустрінуться з кожним громадянином Радянської держави і,\nопитавши його, занесуть дані у переписний лист  .\n    див.  .\n  Одна з фігур гри в городки.')]

# %%
test_set = list(zip(test_data, test_labels))

# %%
for idx, item in enumerate(test_set):
    print("Index:", idx)
    print("Sense:", item[1])
    print("Sample:", item[0])
    print("------------")
# Out:
# Index: 0
# Sense: 4
# Sample: ['До', 'речі', ',', 'тоді', 'ж', 'було', 'вирішено', ',', 'що', 'після', 'двотижневого', 'перебування', 'по', 'домівках', 'усі', 'знову', 'зберуться', 'до', 'козацького', 'війська', ',', 'щоб', 'заслухати', '«', 'реляцію', ',', 'яку', 'привезуть', 'посли', '»', '.', '29', 'червня', 'в', 'Чигирині', 'знову', 'збирається', '«', 'чорна', '»', 'рада', 'для', 'заслухання', 'листа', 'від', 'А', '.', 'Кисіля', 'та', 'підготовки', 'відповіді', '.']
# ------------
# Index: 1
# Sense: 4
# Sample: ['Про', 'ці', 'обставини', 'директор', 'краєзнавчого', 'музею', 'неодноразово', 'листами', 'повідомляв', 'голів', 'Любомльської', 'райдержадміністрації', 'та', 'районної', 'ради', ',', 'а', 'також', 'управління', 'культури', 'Волинської', 'облдержадміністрації', '.']
# ------------
# Index: 2
# Sense: 1
# Sample: ['Через', 'кілька', 'років', 'народиться', 'і', 'другий', 'цикл', '—', '«', 'Кримські', 'відгуки', '»', ',', 'до', 'якого', 'увійдуть', '«', 'Імпровізація', '»', ',', '«', 'Уривки', 'з', 'листа', '»', ',', '«', 'Мрії', '»', ',', 'драматична', 'поема', '«', 'Іфігенія', 'в', 'Тавриді', '»', ',', '«', 'Весна', 'зимова', '»', '…', 'Цей', 'цикл', '—', 'усе', 'пережите', 'Лесею', 'в', 'Ялті', 'з', 'червня', '1897', 'до', 'червня', '1898', 'року', '…']
# ------------
# Index: 3
# Sense: 1
# Sample: ['В', 'одному', 'з', 'листів', 'Леся', 'відзначила', ':', '«', 'Нам', 'з', 'Кленею', 'так', 'добре', '»', '.']
# ------------
# Index: 4
# Sense: 4
# Sample: ['Відповідь', 'була', 'дана', 'майже', 'така', ',', 'як', 'і', 'в', 'знаменитому', 'листі', 'запорожців', 'до', 'турецького', 'султана', '...']
# ------------
# Index: 5
# Sense: 1
# Sample: ['У', 'письмових', 'джерелах', 'Петриківка', 'вперше', 'згадується', 'в', 'листі', 'кошового', 'отамана', 'Петра', 'Калнишевського', 'митрополитові', 'Київському', ',', 'де', 'він', 'просить', 'дозволу', 'перенести', 'сюди', 'Свято', '-', 'Георгіївську', 'церкву', 'з', 'сусіднього', 'села', ',', 'що', 'постійно', 'страждало', 'від', 'повеней', '.']
# ------------
# Index: 6
# Sense: 1
# Sample: ['Середи', 'них', '–', '«', 'Лист', 'до', 'Густава', 'Гусака', '»', ',', '«', 'Політика', 'і', 'сумління', '»', ',', '«', 'Історії', 'й', 'тоталітаризм', '»', '.']
# ------------
# Index: 7
# Sense: 1
# Sample: ['Відповідно', 'до', 'листа', 'МОН', 'України', 'щодо', 'викладання', 'економіки', 'в', '2006', '/', '2007', 'н', '.', 'р', '.', ',', 'на', 'початок', 'року', 'було', 'підготовлено', 'навчально', '-', 'методичне', 'забезпечення', 'для', 'учнів', 'і', 'вчителів', '(', 'навчальні', 'програми', ',', 'підручники', 'і', 'посібники', ',', 'збірники', 'завдань', 'і', 'задач', ',', 'інтегрований', 'електронний', 'комплекс', ',', 'навчальну', 'програму', 'курсів', 'підвищення', 'кваліфікації', 'вчителів', ')', ',', 'організовано', 'регіональні', 'центри', 'економічної', 'освіти', ',', 'за', 'допомогою', 'яких', 'проводилась', 'підготовка', 'вчителів', 'у', 'курсовий', 'і', 'міжкурсовий', 'періоди', ',', 'створено', 'Асоціацію', 'вчителів', 'економіки', ',', 'продовжувалося', 'видання', 'фахових', 'журналів', 'та', 'ін', '.']
# ------------
# Index: 8
# Sense: 5
# Sample: ['Аналіз', 'методичних', 'листів', 'МОН', 'України', 'щодо', 'викладання', 'у', 'школах', 'економіки', 'у', '2001', '–', '2014', 'роках', 'засвідчив', ',', 'що', 'держава', 'вбачала', 'метою', 'економічної', 'освіти', 'і', 'виховання', 'учнів', 'формування', 'в', 'них', 'економічного', 'мислення', ',', 'готовності', 'свідомо', 'діяти', ',', 'застосовувати', 'отримані', 'знання', 'на', 'практиці', '.']
# ------------
# Index: 9
# Sense: 1
# Sample: ['А', 'коли', 'закрили', 'станцію', ',', 'саме', 'Хіромі', 'був', 'першим', ',', 'хто', 'підтримав', 'дівчинку', 'та', 'запропонував', 'написати', 'листа', 'до', 'керівництва', 'залізниці', '.']
# ------------
# Index: 10
# Sense: 4
# Sample: ['Розказував', 'Рей', 'про', 'свої', 'шкільні', 'роки', 'і', 'спонукав', 'її', 'до', 'написання', 'листа', 'керівництву', 'залізниці', ',', 'адже', 'це', 'так', 'важливо', '—', 'отримати', 'освіту', '.']
# ------------
# Index: 11
# Sense: 1
# Sample: ['Рей', 'кілька', 'днів', 'відмахувалась', 'від', 'думок', ',', 'а', 'потім', 'таки', 'написала', 'той', 'лист', '.']
# ------------
# Index: 12
# Sense: 1
# Sample: ['Дівчина', 'написала', 'листа', 'до', 'керівництва', 'залізниці', '.']
# ------------
# Index: 13
# Sense: 1
# Sample: ['Всі', 'мешканці', 'селища', 'підписали', 'лист', '.']
# ------------
# Index: 14
# Sense: 1
# Sample: ['Лист', 'було', 'відправлено', '.']
# ------------
# Index: 15
# Sense: 1
# Sample: ['Дизайнером', 'цих', 'інформаційних', 'листів', 'була', 'бориспільська', 'художниця', 'Тетяна', 'Кучмій', '.']
# ------------
# Index: 16
# Sense: 2
# Sample: ['І', 'тут', 'він', 'передає', 'мені', 'лист', 'від', 'матері', 'й', 'від', 'Петра', 'Григоровича', ',', 'в', 'якому', 'Григоренко', 'повідомляє', ',', 'що', 'це', 'учень', 'відомого', 'адвоката', 'Софії', 'Каллістратової', 'Микола', 'Монахов', ',', 'і', 'просить', 'не', 'відмовлятися', 'від', 'захисту', ',', 'оскільки', 'через', 'адвоката', 'він', 'зможе', 'отримувати', 'інформацію', 'про', 'хід', 'процесу', '.']
# ------------
# Index: 17
# Sense: 1
# Sample: ['Заохочували', 'дитячі', 'вистави', 'з', 'переодяганнями', ';', 'виставки', 'малюнків', ',', 'що', 'їх', 'розвішували', 'на', 'дверях', ';', 'листи', ',', 'написані', 'крейдою', 'на', 'дверцятах', 'старої', 'шафи', 'на', 'горищі', ';', 'кулінарні', 'експерименти', ',', 'часто', 'невдалі', ';', 'домашні', 'газети', 'з', 'карикатурами', 'та', 'фотографіями', ';', 'колективні', 'перегляди', 'діафільмів', '(', 'дехто', 'їх', 'іще', 'пам’ятає', ')', 'та', 'багато', 'іншого', '...']
# ------------
# Index: 18
# Sense: 1
# Sample: ['Зберігся', 'щодо', 'цього', 'лист', 'В', '.', 'Ясинського', 'до', 'Л', '.', 'Барановича', ',', 'в', 'якому', 'ректор', 'сам', 'вельми', 'уболівав', 'за', 'цю', 'трагедію', '.']
# ------------
# Index: 19
# Sense: 4
# Sample: ['Усі', 'соціальні', 'мережі', 'мають', 'приблизно', 'однакові', 'можливості', ':', 'можна', 'додавати', 'користувачів', 'у', 'список', 'друзів', '(', 'щоб', 'потім', 'швидко', 'знайти', 'людину', ')', ',', 'писати', 'листи', 'чи', 'короткі', 'повідомлення', '.']
# ------------
# Index: 20
# Sense: 1
# Sample: ['ЯКЩО', 'ТОБІ', 'НІ', 'ДО', 'ЧОГО', 'ЦІЛИЙ', 'АРХІВ', ',', 'АЛЕ', 'ТРАПИЛОСЯ', 'ТАК', ',', 'ЩО', 'ТРЕБА', 'ЗБЕРЕГТИ', 'В', 'МЕРЕЖІ', 'ЯКИЙСЬ', 'ФАЙЛ', ',', 'МОЖЕШ', 'СТВОРИТИ', 'У', 'СВОЇЙ', 'ЕЛЕКТРОННІЙ', 'СКРИНЬЦІ', 'ЛИСТ', '-', 'ЧЕРНЕТКУ', 'Й', 'ПРИЄДНАТИ', 'ПОТРІБНІ', 'ДОКУМЕНТИ', '.', 'ЗГОДОМ', 'ВІДКРИЄШ', 'ЇХ', 'НА', 'БУДЬ', '-', 'ЯКОМУ', 'ПІД’ЄДНАНОМУ', 'ДО', 'МЕРЕЖІ', 'ВЕРСТАКУ', '.']
# ------------
# Index: 21
# Sense: 4
# Sample: ['Відтак', 'час', 'від', 'часу', 'до', 'Твоєї', 'скриньки', 'будуть', 'надходити', 'листи', 'про', 'те', ',', 'що', 'нового', 'трапилося', 'у', 'світі', 'або', 'що', 'нового', 'з’явилося', 'на', 'сайті', ',', 'яким', 'Ти', 'цікавишся', '.']
# ------------
# Index: 22
# Sense: 4
# Sample: ['Лист', 'може', 'містити', 'посилання', 'на', 'сторінку', 'з', 'докладним', 'повідомленням', '.']
# ------------
# Index: 23
# Sense: 1
# Sample: ['Але', 'якщо', 'підписок', 'буде', 'дуже', 'багато', ',', 'Твоя', 'електронна', 'скринька', 'може', 'вщерть', 'заповнитися', ',', 'і', 'в', 'тій', 'плутанині', 'позагублюються', 'справді', 'важливі', 'листи', '.']
# ------------
# Index: 24
# Sense: 1
# Sample: ['Тож', 'не', 'переборщи', 'з', 'ними', 'й', 'у', 'разі', 'чого', 'натискай', 'на', 'посилання', 'в', 'кінці', 'листа', ':', '«', 'Відписатися', '»', '.']
# ------------
# Index: 25
# Sense: 1
# Sample: ['Пригадуєш', 'приказку', ',', 'яку', 'приніс', 'наш', 'служка', 'Остап', 'зі', 'свого', 'Світу', 'Замерзлого', 'Сонця', ':', '«', 'Журавель', 'у', 'небесах', 'малює', 'веселки', '»', '?', 'А', 'значення', ',', 'ти', 'не', 'забув', 'значення', '?', 'Вважай', ',', 'що', 'цей', 'лист', 'така', 'собі', 'веселка', ',', 'недарма', 'ж', 'у', 'моєму', 'краї', 'колись', 'журавлів', 'кликали', 'веселиками', '.']
# ------------
# Index: 26
# Sense: 1
# Sample: ['Ображена', 'на', 'тебе', 'за', 'зради', ',', 'ображена', 'на', 'себе', ',', 'що', 'мушу', 'прощатися', 'отак', 'по', '-', 'дикунськи', ',', 'листом', '.']
# ------------
# Index: 27
# Sense: 4
# Sample: ['Колись', 'вона', 'хотіла', 'писати', 'на', 'них', 'листи', 'йому', '.']
# ------------
# Index: 28
# Sense: 4
# Sample: ['-', 'Хочу', 'писати', 'на', 'них', 'листи', '.']
# ------------
# Index: 29
# Sense: 2
# Sample: ['А', 'листів', 'мені', 'писати', 'не', 'треба', '.']
# ------------
# Index: 30
# Sense: 1
# Sample: ['Щороку', 'Національна', 'радіокомпанія', 'отримує', 'понад', '15', 'тисяч', 'листів', 'із', 'радіодиктантом', '.']
# ------------
# Index: 31
# Sense: 1
# Sample: ['Листи', 'надсилають', 'не', 'лише', 'слухачі', 'з', 'усіх', 'областей', 'України', ',', 'а', 'й', 'із', '-', 'за', 'кордону', ':', 'Росії', ',', 'Білорусі', ',', 'Молдови', ',', 'Німеччини', ',', 'Бельгії', 'та', 'інших', 'країн', '.']
# ------------
# Index: 32
# Sense: 1
# Sample: ['Переможці', 'акції', 'визначаються', 'по', 'тому', ',', 'як', 'отримано', 'останній', 'лист', '(', '2011', 'року', 'таких', 'листів', 'було', 'понад', '17', 'тисяч', ')', '.']
# ------------
# Index: 33
# Sense: 4
# Sample: ['Переписувач', 'інтерв’ює', 'особу', 'за', 'питаннями', ',', 'що', 'містяться', 'в', 'переписному', 'листі', '(', 'своєрідна', 'анкета', ')', ',', 'та', 'заповнює', 'його', '.']
# ------------
# Index: 34
# Sense: 4
# Sample: ['Особи', ',', 'що', 'переписуються', ',', 'самі', 'заповнюють', 'переписний', 'лист', ',', 'а', 'переписувач', 'лише', 'перевіряє', 'правильність', 'заповнення', '.']
# ------------
# Index: 35
# Sense: 1
# Sample: ['У', 'сутінках', 'я', 'довго', 'вдивлявся', 'в', 'заплутану', 'в', 'густому', 'гіллі', 'й', 'шелесткому', 'листі', 'зеленувату', 'темряву', 'наді', 'мною', ',', 'аж', 'поки', 'запаморочилося', 'в', 'голові', '.']
# ------------
# Index: 36
# Sense: 1
# Sample: ['Або', 'приходить', 'до', 'банку', 'людина', 'за', 'позикою', 'і', 'приносить', 'лист', 'із', 'фірми', ',', 'де', 'працює', '.']
# ------------
# Index: 37
# Sense: 4
# Sample: ['Люблю', ',', 'коли', 'у', 'поштовій', 'скриньці', 'знаходжу', 'листа', '.']
# ------------
# Index: 38
# Sense: 1
# Sample: ['Звернувся', 'з', 'листом', 'до', 'майстрів', ',', 'хто', 'б', 'міг', 'навчити', '.']
# ------------
# Index: 39
# Sense: 3
# Sample: ['Навіть', 'бачила', 'сон', ':', 'як', 'лежить', 'вона', 'на', 'опалому', 'листі', 'поруч', 'з', 'мертвим', 'ведмедем', 'і', 'мертвою', 'сарною', ',', 'а', 'сріблястий', 'туман', 'хвилями', 'котиться', 'з', 'височезних', 'буків', 'та', 'дубів', '.']
# ------------
# Index: 40
# Sense: 1
# Sample: ['На', 'підставі', 'цих', 'даних', 'міський', 'голова', 'надіслав', 'лист', 'в', '.', 'о', '.', 'начальника', 'Державної', 'інспекції', 'контролю', 'за', 'цінами', 'у', 'Хмельницькій', 'області', 'Дмитру', 'Ягодину', 'з', 'проханням', 'включити', 'до', 'плану', 'перевірок', 'суб’єктів', 'господарювання', ',', 'які', 'здійснюють', 'підприємницьку', 'діяльність', 'в', 'аптеках', 'у', 'різних', 'мікрорайонах', 'міста', ',', 'і', 'залучити', 'при', 'їх', 'проведенні', 'працівників', 'управління', 'економіки', 'міської', 'ради', '.']
# ------------
# Index: 41
# Sense: 1
# Sample: ['До', 'вази', 'долучався', 'завірений', 'нотаріусом', 'лист', ',', 'в', 'якому', 'повідомлялося', ',', 'що', 'автор', 'винаходу', ',', 'на', 'жаль', ',', 'помилився', 'в', 'розрахунках', 'і', 'тепер', 'завзято', 'працює', 'над', 'новим', 'проектом', ',', 'а', 'саме', ':', 'над', 'окулярами', ',', 'які', 'світитимуться', 'вночі', ',', 'і', 'якщо', 'пані', 'Шумінська', 'зацікавляться', 'інвестуванням', ',', 'винахідник', 'готовий', 'назвати', 'дивовижні', 'окуляри', 'на', 'її', 'честь', '.']
# ------------
# Index: 42
# Sense: 1
# Sample: ['Юрків', 'родич', ',', 'член', 'ОУН', ',', 'день', 'відо', 'дня', 'виглядав', 'братанича', ',', 'дізнавшись', 'з', 'листа', 'від', 'брата', ',', 'що', 'племінник', 'уцілів', 'у', 'концтаборі', '.']
# ------------
# Index: 43
# Sense: 2
# Sample: ['Степанко', 'раптом', 'подумав', ',', 'що', 'це', 'ж', 'Щедрик', 'для', 'нього', 'так', 'старався', ',', 'збирав', 'по', 'однесенькому', 'горішку', 'на', 'обчухраній', 'ліщині', 'й', 'складав', 'на', 'пеньок', ',', 'аби', 'Степанко', 'не', 'йшов', 'додому', 'з', 'порожнім', 'козубцем', ',', 'бо', 'не', 'можна', 'йти', 'впорожні', 'з', 'їхнього', 'щедрого', 'пралісу', ';', 'він', 'так', 'старався', ',', 'цей', 'Щедрик', ',', 'що', 'з', 'обнесених', 'кущів', 'нарвав', 'ще', 'он', 'скільки', 'горіхів', '(', 'мабуть', ',', 'жоден', 'не', 'сховався', 'від', 'нього', 'у', 'листі', ')', ',', 'а', 'Степанко', 'не', 'взяв', 'їх', 'і', 'дременув', 'світ', 'за', 'очі', ',', 'ніби', 'погребував', '.']
# ------------
# Index: 44
# Sense: 4
# Sample: ['Зокрема', ',', 'до', 'Державного', 'реєстру', 'внесено', 'Акт', 'проголошення', 'незалежності', 'України', '24', 'серпня', '1991', 'р', '.', ',', 'Заповіт', 'Гетьмана', 'Української', 'держави', 'Павла', 'Скоропадського', '3', 'серпня', '1918', 'р', '.', 'з', 'автографом', 'і', 'сургучевою', 'печаткою', ',', 'Універсал', 'Директорії', 'Української', 'Народної', 'Республіки', 'про', 'злуку', 'з', 'Західно', '-', 'Українською', 'Народною', 'Республікою', '22', 'січня', '1919', 'року', ',', 'Закон', 'про', 'громадянство', 'Української', 'Народної', 'Республіки', '15', 'листопада', '1921', 'р', '.', ',', 'вірші', 'Т', '.', 'Г', '.', 'Шевченка', '«', 'Думка', '»', '1838', 'р', '.', ',', '«', 'Бандуристе', ',', 'орле', 'сизий', '!', '»', '1840', 'р', '.', ',', '«', 'Миколі', 'Івановичу', 'Костомарову', '»', '1847', 'р', '.', ',', '«', 'Сон', '»', '1859', 'р', '.', ',', 'лист', 'видатного', 'вченого', '-', 'хіміка', ',', 'професора', 'Д', '.', 'І', '.', 'Менделєєва', ',', 'студентську', 'роботу', 'Івана', 'Франка', '«', 'Про', 'Лукіана', 'і', 'його', 'сучасність', '»', ',', 'грамоти', 'на', 'пергаменті', 'XIII', '–', 'XV', 'століть', 'та', 'інші', '.']
# ------------
# Index: 45
# Sense: 1
# Sample: ['У', 'зв’язку', 'з', 'малюнками', 'до', 'останнього', ',', 'А', '.', 'Ждаха', 'згадується', ',', 'зокрема', ',', 'в', 'листах', 'до', 'випускника', 'Єлисаветградського', 'реального', 'училища', ',', 'українського', 'мецената', 'Є', '.', 'Чикаленка', '1901', 'року', ',', 'який', 'виділив', 'гроші', 'на', 'їх', 'виконання', ',', 'і', 'щодо', 'нереалізованого', 'проекту', 'видання', '1903', 'року', '.']
# ------------
# Index: 46
# Sense: 1
# Sample: ['Живлять', 'рослини', 'по', 'листу', ',', 'норма', 'внесення', 'препаратів', 'становить', '2', '–', '5', 'л', '/', 'га', '.']
# ------------
# Index: 47
# Sense: 1
# Sample: ['Учитель', '-', 'росіянин', 'із', 'російського', 'провінційного', 'містечка', ',', 'який', 'присвятив', 'Україні', 'декілька', 'віршів', 'і', 'за', 'це', 'поплатився', ',', 'написав', 'листа', 'в', 'редакцію', '«', 'Експресу', '»']
# ------------
# Index: 48
# Sense: 4
# Sample: ['Малі', 'хитруни', 'знали', ',', 'що', 'владика', 'обов’язково', 'відгукнеться', 'на', 'їхній', 'лист', '.']
# ------------
# Index: 49
# Sense: 1
# Sample: ['У', 'листі', 'до', 'приятельки', 'Софія', 'Шептицька', 'написала', ',', 'що', 'це', 'хлоп’я', 'Господь', 'хоче', 'мати', 'своїм', '.']
# ------------

# %%
corrected_labels = test_labels.copy()
corrected_labels[2] = 4
corrected_labels[3] = 4
corrected_labels[5] = 4 
corrected_labels[6] = 5
corrected_labels[7] = 5
corrected_labels[9] = 4
corrected_labels[11] = 4
corrected_labels[12] = 4
corrected_labels[13] = 4
corrected_labels[14] = 4
corrected_labels[15] = 4
corrected_labels[16] = 4
corrected_labels[17] = 4
corrected_labels[18] = 4
corrected_labels[20] = 4
corrected_labels[23] = 4
corrected_labels[24] = 4
corrected_labels[25] = 2
corrected_labels[26] = 4
corrected_labels[29] = 4
corrected_labels[30] = 4
corrected_labels[31] = 4
corrected_labels[32] = 4
corrected_labels[36] = 5
corrected_labels[38] = 5
corrected_labels[39] = 1
corrected_labels[40] = 4
corrected_labels[41] = 5
corrected_labels[42] = 4
corrected_labels[43] = 1
corrected_labels[45] = 4
corrected_labels[47] = 4
corrected_labels[49] = 4

# %%
score = np.sum(np.array(test_labels) == np.array(corrected_labels)) / len(corrected_labels)

# %%
print(f"Baseline quality of Lesk {score * 100:.2f}%")
# Out:
# Baseline quality of Lesk 34.00%

# %% [markdown]
# ## TF-IDF weighting

# %%
signatures = [(idx, collect_bow(sense)) for idx, sense in senses]

# %%
signature_words = {w for s in signatures for w in s[1]}

# %%
signature_words_counts = []
for word in signature_words:
    for sentence in test_data:
        if word in collect_bow(sentence):
            signature_words_counts.append(word)

# %%
docs_count = 50
signature_counter = Counter(signature_words_counts)

# %%
def classify(sentence, word, senses, log=False):
    """
    Find the sense that has the biggest overlap with the word context.
    Use sense 1 as default.
    """
    context = collect_bow(sentence)
    best_sense = 1
    max_overlap = 0
    max_overlap_words = []
    for sense_id, signature in signatures:
        overlap = context.intersection(signature)

        score = np.array([math.log(50, 2 + signature_counter[x]) for x in overlap]).sum()
#         if score == max_overlap and sense_id == 4:
#             best_sense = sense_id
#             max_overlap_words = overlap
            
        if score > max_overlap:
            max_overlap_words = overlap
            max_overlap = score
            best_sense = sense_id
            
       
    if log:
        print(" ".join(sentence))
        print("Best sense:", best_sense)
        print("{} words overlap: {}.\n".format(max_overlap, ", ".join(max_overlap_words)))
    return best_sense

# %%
predicted = [classify(x, word, signatures, log=False) for x in test_data]

# %%
score = np.sum(np.array(predicted) == np.array(corrected_labels)) / len(corrected_labels)

# %%
print(f"Improved quality of Lesk {score * 100:.2f}%")
# Out:
# Improved quality of Lesk 34.00%

# %% [markdown]
# ## Extend the word list

# %%
senses
# Out:
# [(1,
#   '   а. Орган повітряного живлення і\nгазообміну рослин у вигляді тонкої, звичайно зеленої\nпластинки. Лист за листом опадає, Рік за роком\nупливає. Назад не вертає!  ;\nВиноградний лист вирізується з темряви й ніжно тремтить\nразом з тонким вусиком у місячному сяйві  ; \xa0  А я піду на край світа... На\nчужій сторонці Найду кращу [дівчину] або згину, Як\nтой лист на сонці  ; Пішли літа\n[Маланчині] марне з світа, як лист по Дунаю...\n ;  \xa0 Складова частина головки\nкапусти. У відрі стоїть глек з молоком, сир у капустяному\nлисті, біла селянська паляниця  ;\n \xa0   листом,   — плавно, поволі.\n[Штольц:] В зоні виконати, три петлі, два праві й\nдва ліві перевороти.. Падіння листом до шестисот\nметрів  .\n    див.  .\n'),
#  (2,
#   '   у. Те саме, що  . — Я б прикрила твій\nслід листом, щоб його вітер не завіяв, піском не замів, —\nсказала Мелашка  ; Ах, яке ж\nсинє й зоряне небо! І запах цегли — руїн, жовтого\nлисту — аж у голову хмелем  ;\n \xa0 Засушене, рідше свіже листя деяких рослин, що\nвикористовується як приправа або для виготовлення напою\nчи ліків. Яких вже мені ліків не завдавали! Лукаш мене\nнапував листом от чорних порічок  ; Дівчата онде подались Збирати свіжий лист із чаю\n ; Не поспішаючи, він кладе\nв казанок.. сіль, дрібно покришену й підсмажену цибулю\nі лавровий лист  .'),
#  (3,
#   ' Тонкий, щільний шматок або шар\nякого-небудь матеріалу (паперу, заліза, фанери і т. ін.).\nГазорізальник Мамайчук-старший.. щось викроює з\nтовстого сталевого листа  ;\nЦілий вечір Мишуня казився й дурів.. Зачепив неумисно\nй перекинув відро з водою. Упустив фанерного листа,\nна якому лежало тісто  ;\nШиферний лист іде на покрівлю житлових і промислових\nбудівель  .\n'),
#  (4,
#   ' Писаний текст, признач. для повідомлення про\nщо-небудь, для спілкування з кимось на відстані, а\nтакож відповідна поштова кореспонденція. По копійці\nзаробляла [вдова], Копу назбирала. Та до сина лист\nписала, У військо послала — Полегшало  ; Аж двічі Павло прочитав листа зряду. І, як\nце й завжди бувало з ним після Корнійових листів,\nтрохи полегшало ніби  ; — Вам,\nПолю, ось газетки і рекомендований лист, — дістала\nлистоноша пошту з керзової сумки  ;  \xa0 Писане звертання до особи або осіб,\nрозраховане на широке розповсюдження. Кожний студент\nзнає знаменитий лист Бєлінського, як він писав про\nГоголя  .\n'),
#  (5,
#   ' який. Офіційний, грошовий або інший документ.\n[Йоганна (після мовчання):] Хузане, дай мені\nрозлучний лист  ;  \xa0 Документ\nдля записування яких-небудь відомостей. Вони\n[обліковці] обійдуть квартиру за квартирою..,\nзустрінуться з кожним громадянином Радянської держави і,\nопитавши його, занесуть дані у переписний лист  .\n    див.  .\n  Одна з фігур гри в городки.')]

# %%
enrichment = {
    1: "", 
    2: "",
    3: "",
    4: "У', 'листі', 'до', 'приятельки', 'Софія', 'Шептицька', 'написала', ',', 'що', 'це', 'хлоп’я' 'Але', 'якщо', 'підписок', 'буде', 'дуже', 'багато', ',', 'Твоя', 'електронна', 'скринька', 'може', 'вщерть', 'заповнитися' 'У', 'зв’язку', 'з', 'малюнками', 'до', 'останнього', ',', 'А', '.', 'Ждаха', 'згадується', ',', 'зокрема', ',', 'в', 'листах', 'до', 'випускника',  'Відповідно', 'до', 'листа', 'МОН', 'України', 'щодо', 'викладання', 'економіки', 'Ображена', 'на', 'тебе', 'за', 'зради', ',', 'ображена', 'на', 'себе', На підставі цих даних міський голова надіслав 'мешканці', 'селища', 'підписали' 'коли', 'закрили', 'станцію',", 
    5: ""
}

# %%
senses_rich = []
for sid, stext in senses:
    senses_rich.append((sid, stext + enrichment[sid]))

# %%
signatures = [(idx, collect_bow(sense)) for idx, sense in senses_rich]

# %%
predicted = [classify(x, word, signatures, log=False) for x in test_data]

# %%
score = np.sum(np.array(predicted) == np.array(corrected_labels)) / len(corrected_labels)

# %%
print(f"Improved quality of Lesk {score * 100:.2f}%")
# Out:
# Improved quality of Lesk 66.00%

# %% [markdown]
# ### Adjust classifier to corpus

# %%
def classify(sentence, word, senses, log=False):
    """
    Find the sense that has the biggest overlap with the word context.
    Use sense 1 as default.
    """
    context = collect_bow(sentence)
    best_sense = 1
    max_overlap = 0
    max_overlap_words = []
    for sense_id, signature in signatures:
        overlap = context.intersection(signature)

        score = np.array([math.log(50, 2 + signature_counter[x]) for x in overlap]).sum()
        if score == max_overlap and sense_id == 4:
            best_sense = sense_id
            max_overlap_words = overlap
            
        if score > max_overlap:
            max_overlap_words = overlap
            max_overlap = score
            best_sense = sense_id
            
       
    if log:
        print(" ".join(sentence))
        print("Best sense:", best_sense)
        print("{} words overlap: {}.\n".format(max_overlap, ", ".join(max_overlap_words)))
    return best_sense

# %%
predicted = [classify(x, word, signatures, log=False) for x in test_data]

# %%
score = np.sum(np.array(predicted) == np.array(corrected_labels)) / len(corrected_labels)

# %%
print(f"Improved quality of Lesk {score * 100:.2f}%")
# Out:
# Improved quality of Lesk 74.00%

# %% [markdown]
# ## Your task
#
# 1. Choose a word (or a list of words).
# 2. Collect real-world sentences for the word(s).
# 3. Implement Simplified Lesk for disambiguating the word(s).
# 4. Set aside 50 sentences as a test set and manually fix the disambiguation errors that Lesk made. Calculate the quality of WSD by Lesk.
# 5. Improve the quality of WSD by:
# - taking into account word count
# - counting IDF score (log of total number of senses divided by the number of senses where the word was used)
# - extending the word lists for senses in a semi-supervised manner (using the context of words that were disambiguated with high confidence)
